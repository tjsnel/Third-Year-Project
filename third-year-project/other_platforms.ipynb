# %%
import pandas as pd
import numpy as np
import unicodedata
import difflib
import unidecode

# %%
platforms = ["Guardian", "NME1", "Pitchfork", "Spectrum", "DIY", "LAQ", "Gigwise", "Ohm", "Skinny", "Uncut", "UTR"]
paths = [f"C:\\Users\\tommy\\OneDrive\\University\\Year 3\\Third Year Project\\Platform Album Data\\{platform}.csv" for platform in platforms]

# %%
dfs = {platform: pd.read_csv(path, index_col=0) for platform, path in zip(platforms, paths)}

# %%
{platform: df.shape[0] for platform, df in dfs.items()}
# Out:
# {'Guardian': 183479,
#  'NME1': 5052,
#  'Pitchfork': 25396,
#  'Spectrum': 7933,
#  'DIY': 2234,
#  'LAQ': 2153,
#  'Gigwise': 1922,
#  'Ohm': 1488,
#  'Skinny': 3734,
#  'Uncut': 10969,
#  'UTR': 4200}

# %%
dfs = {platform: df.drop_duplicates() for platform, df in dfs.items()}

for platform, df in dfs.items():
    
    # df.drop(columns=["Platform"], axis=1, inplace=True)
    df.loc[:, "Album"] = df["Album"].apply(lambda x: unidecode.unidecode(unicodedata.normalize("NFKD", str(x))))
    df.loc[:, "Artist"] = df["Artist"].apply(lambda x: unidecode.unidecode(unicodedata.normalize("NFKD", str(x))))
    df.loc[:, "Album"] = df["Album"].apply(lambda x: x.strip("'`").replace(".", "").replace(",", "").replace("–", "").replace("-", "").replace(
        "&", "And").lower().replace("' review", "").strip())
    df.loc[:, "Artist"] = df["Artist"].apply(lambda x: x.strip("'`").replace(".", "").replace(",", "").replace("–", "").replace("-", "").replace(
        "&", "And").replace("album review:", "").lower().strip())
    df.rename({"Url": f"{platform}_url"}, axis=1, inplace=True)
    dfs[platform] = df

# %%
df = dfs["Pitchfork"]

for key in list(dfs.keys())[1:]:
    
    pf_merged = pd.merge(df, dfs[key], how="inner", on=["Album", "Artist"])
    print(key, df.shape[0])
    print(pf_merged)
# Out:
# NME1 24549
#      Platform_x          Artist                              Album Platform_y
# 0     Pitchfork        the 1975  being funny in a foreign language        NME
# 1     Pitchfork            tsha                      capricorn sun        NME
# 2     Pitchfork          daphni                             cherry        NME
# 3     Pitchfork         shygirl                              nymph        NME
# 4     Pitchfork          pixies                           doggerel        NME
# ...         ...             ...                                ...        ...
# 2051  Pitchfork      kanye west                  late registration        NME
# 2052  Pitchfork   kings of leon               aha shake heartbreak        NME
# 2053  Pitchfork  the libertines                     the libertines        NME
# 2054  Pitchfork            blur                         think tank        NME
# 2055  Pitchfork     the streets           original pirate material        NME
#
# [2056 rows x 4 columns]
# Pitchfork 24549
#       Platform_x           Artist  \
# 0      Pitchfork    bill callahan
# 1      Pitchfork             palm
# 2      Pitchfork  open mike eagle
# 3      Pitchfork      field medic
# 4      Pitchfork      against me!
# ...          ...              ...
# 24552  Pitchfork          cassius
# 24553  Pitchfork          coldcut
# 24554  Pitchfork    don caballero
# 24555  Pitchfork         mojave 3
# 24556  Pitchfork   neil hamburger
#
#                                                    Album Platform_y
# 0                                                ytia3ia  Pitchfork
# 1                                       nicks and grazes  Pitchfork
# 2                 component system with the auto reverse  Pitchfork
# 3      grow your hair long if you ' re wanting to see...  Pitchfork
# 4                                   reinventing axl rose  Pitchfork
# ...                                                  ...        ...
# 24552                                               1999  Pitchfork
# 24553                                     let us replay!  Pitchfork
# 24554                          singles breaking up vol 1  Pitchfork
# 24555                                        out of tune  Pitchfork
# 24556                          left for dead in malaysia  Pitchfork
#
# [24557 rows x 4 columns]
# Spectrum 24549
#      Platform_x             Artist                   Album Platform_y
# 0     Pitchfork      bill callahan                 ytia3ia   Spectrum
# 1     Pitchfork             daphni                  cherry   Spectrum
# 2     Pitchfork    sun ra arkestra              living sky   Spectrum
# 3     Pitchfork            alvvays                blue rev   Spectrum
# 4     Pitchfork       rome streetz           kiss the ring   Spectrum
# ...         ...                ...                     ...        ...
# 4030  Pitchfork          the knife               deep cuts   Spectrum
# 4031  Pitchfork             loscil                 submers   Spectrum
# 4032  Pitchfork  the white stripes       white blood cells   Spectrum
# 4033  Pitchfork        jan jelinek  loopfindingjazzrecords   Spectrum
# 4034  Pitchfork                gas                     pop   Spectrum
#
# [4035 rows x 4 columns]
# DIY 24549
#      Platform_x                            Artist                  Album  \
# 0     Pitchfork                            willow      <copingmechanism>
# 1     Pitchfork                            alex g   god save the animals
# 2     Pitchfork                        maya hawke                   moss
# 3     Pitchfork                               djo                 decide
# 4     Pitchfork               death cab for cutie        asphalt meadows
# ...         ...                               ...                    ...
# 1280  Pitchfork                      popstrangers                fortuna
# 1281  Pitchfork                  sharon van etten           are we there
# 1282  Pitchfork  the pains of being pure at heart        days of abandon
# 1283  Pitchfork                              paws  youth culture forever
# 1284  Pitchfork                        phantogram                 voices
#
#      Platform_y
# 0           DIY
# 1           DIY
# 2           DIY
# 3           DIY
# 4           DIY
# ...         ...
# 1280        DIY
# 1281        DIY
# 1282        DIY
# 1283        DIY
# 1284        DIY
#
# [1285 rows x 4 columns]
# LAQ 24549
#      Platform_x             Artist                                  Album  \
# 0     Pitchfork              sorry                      anywhere but here
# 1     Pitchfork         gilla band                            most normal
# 2     Pitchfork               tsha                          capricorn sun
# 3     Pitchfork               disq  desperately imagining someplace quiet
# 4     Pitchfork             daphni                                 cherry
# ...         ...                ...                                    ...
# 1065  Pitchfork  animal collective                          painting with
# 1066  Pitchfork         essaie pas              demain est une autre nuit
# 1067  Pitchfork    london o'connor                                      o
# 1068  Pitchfork        protomartyr               no passion all technique
# 1069  Pitchfork      susumu yokota                                 symbol
#
#      Platform_y
# 0           LAQ
# 1           LAQ
# 2           LAQ
# 3           LAQ
# 4           LAQ
# ...         ...
# 1065        LAQ
# 1066        LAQ
# 1067        LAQ
# 1068        LAQ
# 1069        LAQ
#
# [1070 rows x 4 columns]
# Gigwise 24549
#     Platform_x           Artist                              Album Platform_y
# 0    Pitchfork         the 1975  being funny in a foreign language    Gigwise
# 1    Pitchfork            sorry                  anywhere but here    Gigwise
# 2    Pitchfork          alvvays                           blue rev    Gigwise
# 3    Pitchfork  yeah yeah yeahs                       cool it down    Gigwise
# 4    Pitchfork           alex g               god save the animals    Gigwise
# ..         ...              ...                                ...        ...
# 370  Pitchfork     lana del rey                          honeymoon    Gigwise
# 371  Pitchfork   the libertines           anthems for doomed youth    Gigwise
# 372  Pitchfork     sleigh bells                    reign of terror    Gigwise
# 373  Pitchfork   arctic monkeys                             humbug    Gigwise
# 374  Pitchfork      the strokes                         is this it    Gigwise
#
# [375 rows x 4 columns]
# Ohm 24549
#     Platform_x                Artist                              Album  \
# 0    Pitchfork         bill callahan                            ytia3ia
# 1    Pitchfork              the 1975  being funny in a foreign language
# 2    Pitchfork            gilla band                        most normal
# 3    Pitchfork                daphni                             cherry
# 4    Pitchfork               alvvays                           blue rev
# ..         ...                   ...                                ...
# 712  Pitchfork  charlotte gainsbourg                               rest
# 713  Pitchfork          taylor swift                         reputation
# 714  Pitchfork             fever ray                             plunge
# 715  Pitchfork           protomartyr           no passion all technique
# 716  Pitchfork                 swans                    children of god
#
#     Platform_y
# 0          Ohm
# 1          Ohm
# 2          Ohm
# 3          Ohm
# 4          Ohm
# ..         ...
# 712        Ohm
# 713        Ohm
# 714        Ohm
# 715        Ohm
# 716        Ohm
#
# [717 rows x 4 columns]
# Skinny 24549
#      Platform_x         Artist                              Album Platform_y
# 0     Pitchfork  bill callahan                            ytia3ia     Skinny
# 1     Pitchfork       the 1975  being funny in a foreign language     Skinny
# 2     Pitchfork     gilla band                        most normal     Skinny
# 3     Pitchfork        alvvays                           blue rev     Skinny
# 4     Pitchfork        shygirl                              nymph     Skinny
# ...         ...            ...                                ...        ...
# 1600  Pitchfork   scott walker                          the drift     Skinny
# 1601  Pitchfork           tool                         10000 days     Skinny
# 1602  Pitchfork            toy                                toy     Skinny
# 1603  Pitchfork      the knife                       silent shout     Skinny
# 1604  Pitchfork   neil diamond                           12 songs     Skinny
#
# [1605 rows x 4 columns]
# Uncut 24549
#      Platform_x               Artist                          Album Platform_y
# 0     Pitchfork        bill callahan                        ytia3ia      Uncut
# 1     Pitchfork               pixies                       doggerel      Uncut
# 2     Pitchfork             lambchop                      the bible      Uncut
# 3     Pitchfork      makaya mccraven                 in these times      Uncut
# 4     Pitchfork           beth orton                  weather alive      Uncut
# ...         ...                  ...                            ...        ...
# 1162  Pitchfork      pilot to gunner           games at high speeds      Uncut
# 1163  Pitchfork   lift to experience  the texasjerusalem crossroads      Uncut
# 1164  Pitchfork       laura cantrell         not the tremblin' kind      Uncut
# 1165  Pitchfork            nada surf           the proximity effect      Uncut
# 1166  Pitchfork  the magnetic fields                  69 love songs      Uncut
#
# [1167 rows x 4 columns]
# UTR 24549
#      Platform_x                Artist                          Album  \
# 0     Pitchfork         bill callahan                        ytia3ia
# 1     Pitchfork  bonny light horseman            rolling golden holy
# 2     Pitchfork               alvvays                       blue rev
# 3     Pitchfork      titus andronicus               the will to live
# 4     Pitchfork                pixies                       doggerel
# ...         ...                   ...                            ...
# 1777  Pitchfork    lift to experience  the texasjerusalem crossroads
# 1778  Pitchfork                 doves                     lost souls
# 1779  Pitchfork         saint etienne                 sound of water
# 1780  Pitchfork           bright eyes             fevers and mirrors
# 1781  Pitchfork       sarah cracknell                       lipslide
#
#      Platform_y
# 0           UTR
# 1           UTR
# 2           UTR
# 3           UTR
# 4           UTR
# ...         ...
# 1777        UTR
# 1778        UTR
# 1779        UTR
# 1780        UTR
# 1781        UTR
#
# [1782 rows x 4 columns]
