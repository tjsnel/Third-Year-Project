# %%
# %matplotlib inline
import pandas as pd
from sklearn.metrics import roc_auc_score, roc_curve, det_curve
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np

# %%
results = pd.read_csv("C:\\Users\\tommy\\OneDrive\\University\\Year 3\\Third Year Project\\Platform Album Data\\test_results.csv", index_col=0)
results = results.loc[results["Album"] == "cavalcade"]

# %%
results_dic = {word: prob for word, prob in zip(results.loc[:, "Text"], results.loc[:, "pos_prob"])}

# %%
cloud = WordCloud().generate_from_frequencies(results_dic)

# %%
plt.imshow(cloud)
