# %%
# %matplotlib inline
import pandas as pd
from sklearn.metrics import roc_auc_score, roc_curve, det_curve
import matplotlib.pyplot as plt
import plotly.express as px

# %%
results = pd.read_csv("C:\\Users\\tommy\\OneDrive\\University\\Year 3\\Third Year Project\\Platform Album Data\\test_results.csv", index_col=0)

# %%
fpr, tpr, thresholds = roc_curve(results.loc[:, "Desired"], results.loc[:, "pos_prob"])

# %%
px.line(x=fpr, y=tpr, labels={
    "x": "False Positive Rate",
    "y": "True Positive Rate"})
